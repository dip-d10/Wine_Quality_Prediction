# %%
import yaml

yaml_file_path = "test.yaml"

# open the yaml file and load it contents

with open(yaml_file_path, 'r') as yaml_file:
    data = yaml.safe_load(yaml_file)

# %%
print(data)
# Out:
# {'name': 'dip', 'email': 'sumantajyoti795@gmail.com'}
